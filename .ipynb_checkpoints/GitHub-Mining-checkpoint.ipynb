# %% [markdown]
# 1- Importing requests it allows you to send HTTP requests, without the need for manual labor. There's no need to manually add query strings to your URLs.
#
# 2- Importing getpass for a secure password prompt
#
# 3- Json is the exclusive format GitHub API sends data.

# %%
import requests
#from getpass import getpass
import json
import pandas as pd
from github import Github
import networkx as nx
import numpy as np
import ast

# %% [markdown]
# Acquiring OAuth Token..
#
# Quick reminder: OAuth is an open standard for access delegation, commonly used as a way for Internet users to grant websites or applications access to their information on other websites but without giving them the passwords.

# %%
username = '' #put ur Github user name here! 
password = '' #put ur Github password name here! 
#Credentials are transmitted over a secure SSL connection
url = 'https://api.github.com/authorizations'
note = 'Aquiring_token'
post_data = {'scopes':['repo'],'note': note }
response = requests.post(url,auth = (username, password),data = json.dumps(post_data),) # Mohim this response needs input in this format dunno why!
print("API response:", response.text)
print("Your OAuth token is", response.json()[token])

# %%
token='1b1fc8ab13d142cee8e08254dd2c9218b34aadd3'

# %% [markdown]
# For now we'll try to list a user's followers using User Followers API

# %%
repo_user='tensorflow'
repo='tensorflow'

# %% [markdown]
# GitHub identifies contributors by author email address. This endpoint groups contribution counts by GitHub user, which includes all associated email addresses. To improve performance, only the first 500 author email addresses in the repository link to GitHub users. The rest will appear as anonymous contributors without associated GitHub user information.

# %%
from_initial_followship_dict={}
to_initial_followship_dict={}
client = Github(token,per_page=100)
user = client.get_user(repo_user)
repo = user.get_repo(repo)
contributors = [ s for s in repo.get_contributors() ]
print("Number of contributors",len(contributors))
for user in contributors:
    from_initial_followship_dict[user.login]=[follower for follower in user.get_followers()]
# Out:
# Number of contributors 372

# %%
for user in contributors:
    to_initial_followship_dict[user.login]=[follower for follower in user.get_following()]

# %%
import numpy as np
l=np.ndarray(shape=(0,3),dtype=str)
l=np.append(l,[[4,4,4]],axis=0)
l=np.append(l,[[4,5,5]],axis=0)
l=np.append(l,[[4,4,0]],axis=0)
l=np.append(l,[[4,4,0]],axis=0)
l=np.append(l,[[4,4,0]],axis=0)
l=np.append(l,[[4,4,0]],axis=0)
l
pd.DataFrame(data=l).drop_duplicates()

l=[element.login for element in contributors]
"larrytin" in l
# Out:
# True

# %%
l=np.ndarray(shape=(0,3),dtype=str)

#Followers of contributors:
for contributor in from_initial_followship_dict.keys():
    for follower in from_initial_followship_dict[contributor]:
        l=np.append(l,[[contributor,follower.login,"contributer"]],axis=0)

#The followed by contributors:
for contributor in to_initial_followship_dict.keys():
    for followed in to_initial_followship_dict[contributor]:
        if followed in contributors:
            l=np.append(l,[[followed.login,contributor,"contributer"]],axis=0)
        else:
            l=np.append(l,[[followed.login,contributor,"non-contributer"]],axis=0)

# %%
followship_data_frame=pd.DataFrame(data=l)
followship_data_frame.drop_duplicates()
# Out:
#                            0               1                2
# 0      tensorflower-gardener      qiaohaijun      contributer
# 1      tensorflower-gardener        lukemetz      contributer
# 2      tensorflower-gardener        chrisber      contributer
# 3      tensorflower-gardener           jh-yu      contributer
# 4      tensorflower-gardener      waitingkuo      contributer
# 5      tensorflower-gardener  RogerFederer03      contributer
# 6      tensorflower-gardener         lishali      contributer
# 7      tensorflower-gardener           LJ001      contributer
# 8      tensorflower-gardener      Darwin2011      contributer
# 9      tensorflower-gardener        linzgood      contributer
# 10     tensorflower-gardener            arg0      contributer
# 11     tensorflower-gardener    washingtonxr      contributer
# 12     tensorflower-gardener     frankfqchen      contributer
# 13     tensorflower-gardener      yangzhihao      contributer
# 14     tensorflower-gardener  scau-beyondboy      contributer
# 15     tensorflower-gardener      JefferyVin      contributer
# 16     tensorflower-gardener         spillai      contributer
# 17     tensorflower-gardener      ReidHolmes      contributer
# 18     tensorflower-gardener      jungle-cat      contributer
# 19     tensorflower-gardener    AMANSINGHPRO      contributer
# 20     tensorflower-gardener       vintaylor      contributer
# 21     tensorflower-gardener     doublemetal      contributer
# 22     tensorflower-gardener           dxxzx      contributer
# 23     tensorflower-gardener   DevilAndAngel      contributer
# 24     tensorflower-gardener          nojvek      contributer
# 25     tensorflower-gardener       JaredYeDH      contributer
# 26     tensorflower-gardener      andyfangdz      contributer
# 27     tensorflower-gardener          magmog      contributer
# 28     tensorflower-gardener         kgaipal      contributer
# 29     tensorflower-gardener      varadhjain      contributer
# ...                      ...             ...              ...
# 52398                Cephlin       hprovenza  non-contributer
# 52399                 fwarcs       hprovenza  non-contributer
# 52400               keighrim       hprovenza  non-contributer
# 52401          nkrishnaswamy       hprovenza  non-contributer
# 52402              clayriley       hprovenza  non-contributer
# 52403            ZhangAustin          igormq  non-contributer
# 52404               pascanur          igormq  non-contributer
# 52405               karpathy          igormq  non-contributer
# 52406                bamorim          igormq  non-contributer
# 52407             rbgirshick          igormq  non-contributer
# 52408                soumith          igormq  non-contributer
# 52409           janchorowski          igormq  non-contributer
# 52410            kastnerkyle          igormq  non-contributer
# 52411               mesquita          igormq  non-contributer
# 52412              jcjohnson          igormq  non-contributer
# 52413                  n3011          igormq  non-contributer
# 52414              mambrozio          igormq  non-contributer
# 52415            robertomest          igormq  non-contributer
# 52416                yoonkim          igormq  non-contributer
# 52417                patykov          igormq  non-contributer
# 52418            ShaoqingRen          igormq  non-contributer
# 52419              KayneWest          igormq  non-contributer
# 52420            Hibbert-pku          igormq  non-contributer
# 52421              ryankiros          igormq  non-contributer
# 52422              KaimingHe          igormq  non-contributer
# 52423                 lonnes          igormq  non-contributer
# 52424                  svail          igormq  non-contributer
# 52425              yajiemiao          igormq  non-contributer
# 52426            bluesdog164          igormq  non-contributer
# 52427               wesleylp          igormq  non-contributer
#
# [52057 rows x 3 columns]

# %% [markdown]
# Let's now create our followship Graph, using Networkx.
